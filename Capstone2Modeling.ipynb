# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/Springboard/DataScienceSecondCapstone/data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns # For all our visualization needs.
from sklearn.preprocessing import OneHotEncoder
import statsmodels.api as sm # What does this do? Find out and type here.
from statsmodels.graphics.api import abline_plot # For visualling evaluating predictions.
from sklearn.metrics import mean_squared_error, r2_score # What does this do? Find out and type here.
from sklearn.model_selection import train_test_split # For splitting the data.
from sklearn import linear_model, preprocessing

# %%
data = pd.read_csv('Data.csv')

# %%
# We'll start with single feature regression using the most highly correlated feature doctor_recc_h1n1.
# We will use a standard 75%, 25% Train Test Split
X = data[['doctor_recc_h1n1']]
y = data[['h1n1_vaccine']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 123)
#Quick shape check
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (18570, 1) (6191, 1)
# (18570, 1) (6191, 1)

# %%
#Fit data to model
rModel = linear_model.LinearRegression()
rModel.fit(X_train, y_train)
print(rModel.score(X_train, y_train))
# Out:
# 0.08907701784601052

# %%
X = data.drop(columns=['h1n1_vaccine', 'seasonal_vaccine'])
X = sm.add_constant(X)
y = data[['h1n1_vaccine']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 123)

#Quick shape check
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (18570, 96) (6191, 96)
# (18570, 1) (6191, 1)

# %%
rModel2 = sm.OLS(y_train, X_train.astype(float))

# Fit the model
rModel2_results = rModel2.fit()
